# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import r2_score
from skorch import NeuralNetRegressor
from sklearn.model_selection import GridSearchCV

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load training data
Xtr_loadpath = 'Xtr.csv'
Xts_loadpath = 'Xts.csv'
ytr_loadpath = 'ytr.csv'

Xtr = np.loadtxt(Xtr_loadpath, delimiter=",")
Xts = np.loadtxt(Xts_loadpath, delimiter=",")
ytr = np.loadtxt(ytr_loadpath, delimiter=",")

# %%
# standardize the training data
Xtr_mean = np.mean(Xtr,axis=0)
Xtr_std = np.std(Xtr,axis=0)
ytr_mean = np.mean(ytr)
ytr_std = np.std(ytr)

Xtr_standardized = ((Xtr-Xtr_mean[None,:])/Xtr_std[None,:]) # revise this line as needed
Xts_standardized = ((Xts-Xtr_mean[None,:])/Xtr_std[None,:]) # revise this line as needed
ytr_standardized = ((ytr-ytr_mean)/ytr_std)

# save the standardized training data
Xtr_savepath = 'Xtr_pytorch.csv'
Xts_savepath = 'Xts_pytorch.csv'
ytr_savepath = 'ytr_pytorch.csv'
yts_hat_savepath = 'yts_hat_pytorch.csv'

np.savetxt(Xtr_savepath, Xtr_standardized, delimiter=",")
np.savetxt(Xts_savepath, Xts_standardized, delimiter=",")
np.savetxt(ytr_savepath, ytr_standardized, delimiter=",")

# %%
# Convert the numpy arrays to PyTorch tensors
Xtr_torch = torch.Tensor(Xtr_standardized)
ytr_torch = torch.Tensor(ytr)

batch_size = 100  # size of each batch

# Create a training Dataset
train_ds = torch.utils.data.TensorDataset(Xtr_torch, ytr_torch)
# Creates a training DataLoader from this Dataset
train_loader = torch.utils.data.DataLoader(train_ds, batch_size=batch_size, shuffle=True)

# %%
nin = Xtr.shape[1]
nout = 1

# model = nn.Sequential(
#     nn.Linear(nin, 128*5),
#     nn.ReLU(),
#     nn.Dropout(p=0.5),  # Add dropout layer with probability 0.2
#     nn.Linear(128*5, 64*5),
#     nn.ReLU(),
#     nn.Dropout(p=0.5),  # Add dropout layer with probability 0.2
#     nn.Linear(64*5, 32*5),
#     nn.ReLU(),
#     nn.Dropout(p=0.5),  # Add dropout layer with probability 0.2
#     nn.Linear(32*5, 16*5),
#     nn.ReLU(),
#     nn.Dropout(p=0.5),  # Add dropout layer with probability 0.2
#     nn.Linear(16*5, 8*5),
#     nn.ReLU(),
#     nn.Linear(8*5, 4*5),
#     nn.ReLU(),
#     nn.Linear(4*5, 2*5),
#     nn.ReLU(),
#     nn.Linear(2*5, nout)
# )

model = nn.Sequential(
    nn.Linear(nin, 1262),
    nn.ReLU(),
    nn.Dropout(p=0.5),  # Add dropout layer with probability 0.2
    # nn.Linear(3788, 2187),
    # nn.ReLU(),
    # nn.Dropout(p=0.5),  # Add dropout layer with probability 0.2
    # nn.Linear(2187, 1262),
    # nn.ReLU(),
    # nn.Dropout(p=0.5),  # Add dropout layer with probability 0.2
    nn.Linear(1262, 729),
    nn.ReLU(),
    nn.Dropout(p=0.5),  # Add dropout layer with probability 0.2
    nn.Linear(729, 420),
    nn.ReLU(),
    nn.Dropout(p=0.5),  # Add dropout layer with probability 0.2   
    nn.Linear(420, 243),
    nn.ReLU(),
    nn.Dropout(p=0.5),  # Add dropout layer with probability 0.2  
    nn.Linear(243, 81),
    nn.ReLU(),
    nn.Dropout(p=0.5),  # Add dropout layer with probability 0.2
    nn.Linear(81, 27),
    nn.ReLU(),
    nn.Linear(27, 9),
    nn.ReLU(),
    nn.Linear(9, 3),
    nn.ReLU(),
    nn.Linear(3, nout)
)

print(str(model))
# Out:
# Sequential(
#   (0): Linear(in_features=26, out_features=1262, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.5, inplace=False)
#   (3): Linear(in_features=1262, out_features=729, bias=True)
#   (4): ReLU()
#   (5): Dropout(p=0.5, inplace=False)
#   (6): Linear(in_features=729, out_features=420, bias=True)
#   (7): ReLU()
#   (8): Dropout(p=0.5, inplace=False)
#   (9): Linear(in_features=420, out_features=243, bias=True)
#   (10): ReLU()
#   (11): Dropout(p=0.5, inplace=False)
#   (12): Linear(in_features=243, out_features=81, bias=True)
#   (13): ReLU()
#   (14): Dropout(p=0.5, inplace=False)
#   (15): Linear(in_features=81, out_features=27, bias=True)
#   (16): ReLU()
#   (17): Linear(in_features=27, out_features=9, bias=True)
#   (18): ReLU()
#   (19): Linear(in_features=9, out_features=3, bias=True)
#   (20): ReLU()
#   (21): Linear(in_features=3, out_features=1, bias=True)
# )

# %%
# Choosing the optimizer and loss function

epochs = 1000
lrate = 6e-9
decay = lrate/epochs
lambda1 = lambda epoch: (1-decay)*epoch

opt = optim.Adam(model.parameters(), lr=lrate)
scheduler = optim.lr_scheduler.LambdaLR(opt, lr_lambda=lambda1)
criterion = nn.MSELoss()
#criterion = nn.HuberLoss(reduction='mean', delta=30)
#criterion = nn.L1Loss()

# %%
# training the model
num_epoch = epochs

a_tr_loss = np.zeros([num_epoch])
a_tr_Rsq = np.zeros([num_epoch])

for epoch in range(num_epoch):

    model.train() # put model in training mode
    batch_loss_tr = []
    batch_Rsq_tr = []
    # iterate over training set
    for train_iter, data in enumerate(train_loader):
        x_batch,y_batch = data
        
        y_batch = y_batch.view(-1,1)
        #y_batch = y_batch.type(torch.long)
        
        out = model(x_batch)
        # Compute Loss
        loss = criterion(out,y_batch.type(torch.float))
        batch_loss_tr.append(loss.item())
        # Compute R-square
        Rsq = r2_score(y_batch.type(torch.float).detach().numpy(), out.detach().numpy())
        batch_Rsq_tr.append(Rsq.item())
        # Compute gradients using back propagation
        opt.zero_grad()
        loss.backward()
        # Take an optimization 'step'
        opt.step()
        
    # Take scheduler step
    scheduler.step()
        
    a_tr_loss[epoch] = np.mean(batch_loss_tr) # Compute average loss over epoch
    a_tr_Rsq[epoch] = np.mean(batch_Rsq_tr)
    if (epoch+1) % 10 == 0:
        print('Epoch: {0:2d}   Train Loss: {1:.3f}   '.format(epoch+1, a_tr_loss[epoch])
             + 'R^2: {0:.3f}   '.format(a_tr_Rsq[epoch])
             )
    
with torch.no_grad():
    predict = model(torch.Tensor(Xtr_standardized)).detach().numpy().ravel()

r2 = r2_score(ytr,predict)
print('training R2: ',r2)
# Out:
# Epoch: 10   Train Loss: 10.338   R^2: 0.888
# Epoch: 20   Train Loss: 9.789   R^2: 0.888
# Epoch: 30   Train Loss: 10.115   R^2: 0.894
# Epoch: 40   Train Loss: 9.856   R^2: 0.889
# Epoch: 50   Train Loss: 10.837   R^2: 0.882
# Epoch: 60   Train Loss: 10.018   R^2: 0.894
# Epoch: 70   Train Loss: 10.128   R^2: 0.892
# Epoch: 80   Train Loss: 11.086   R^2: 0.878
# Epoch: 90   Train Loss: 10.235   R^2: 0.889
# Epoch: 100   Train Loss: 10.412   R^2: 0.889
# Epoch: 110   Train Loss: 10.305   R^2: 0.887
# Epoch: 120   Train Loss: 10.111   R^2: 0.883
# Epoch: 130   Train Loss: 10.465   R^2: 0.886
# Epoch: 140   Train Loss: 10.375   R^2: 0.888
# Epoch: 150   Train Loss: 9.977   R^2: 0.889
# Epoch: 160   Train Loss: 10.132   R^2: 0.889
# Epoch: 170   Train Loss: 10.321   R^2: 0.881
# Epoch: 180   Train Loss: 10.627   R^2: 0.888
# Epoch: 190   Train Loss: 9.835   R^2: 0.895
# Epoch: 200   Train Loss: 10.205   R^2: 0.888
# Epoch: 210   Train Loss: 10.352   R^2: 0.890
# Epoch: 220   Train Loss: 10.003   R^2: 0.891
# Epoch: 230   Train Loss: 9.893   R^2: 0.893
# Epoch: 240   Train Loss: 10.106   R^2: 0.888
# Epoch: 250   Train Loss: 9.991   R^2: 0.884
# Epoch: 260   Train Loss: 9.851   R^2: 0.890
# Epoch: 270   Train Loss: 10.285   R^2: 0.887
# Epoch: 280   Train Loss: 10.538   R^2: 0.883
# Epoch: 290   Train Loss: 10.161   R^2: 0.889
# Epoch: 300   Train Loss: 10.079   R^2: 0.887
# Epoch: 310   Train Loss: 9.621   R^2: 0.896
# Epoch: 320   Train Loss: 10.144   R^2: 0.882
# Epoch: 330   Train Loss: 10.022   R^2: 0.887
# Epoch: 340   Train Loss: 10.599   R^2: 0.882
# Epoch: 350   Train Loss: 10.293   R^2: 0.892
# Epoch: 360   Train Loss: 10.476   R^2: 0.885
# Epoch: 370   Train Loss: 9.844   R^2: 0.889
# Epoch: 380   Train Loss: 10.262   R^2: 0.884
# Epoch: 390   Train Loss: 10.465   R^2: 0.883
# Epoch: 400   Train Loss: 10.237   R^2: 0.881
# Epoch: 410   Train Loss: 10.125   R^2: 0.889
# Epoch: 420   Train Loss: 9.879   R^2: 0.893
# Epoch: 430   Train Loss: 9.613   R^2: 0.897
# Epoch: 440   Train Loss: 9.767   R^2: 0.893
# Epoch: 450   Train Loss: 10.273   R^2: 0.887
# Epoch: 460   Train Loss: 10.381   R^2: 0.885
# Epoch: 470   Train Loss: 9.482   R^2: 0.895
# Epoch: 480   Train Loss: 10.134   R^2: 0.879
# Epoch: 490   Train Loss: 10.240   R^2: 0.887
# Epoch: 500   Train Loss: 9.741   R^2: 0.886
# Epoch: 510   Train Loss: 10.001   R^2: 0.888
# Epoch: 520   Train Loss: 10.026   R^2: 0.887
# Epoch: 530   Train Loss: 9.933   R^2: 0.887
# Epoch: 540   Train Loss: 10.266   R^2: 0.887
# Epoch: 550   Train Loss: 10.292   R^2: 0.887
# Epoch: 560   Train Loss: 9.815   R^2: 0.889
# Epoch: 570   Train Loss: 10.085   R^2: 0.890
# Epoch: 580   Train Loss: 9.670   R^2: 0.894
# Epoch: 590   Train Loss: 9.938   R^2: 0.893
# Epoch: 600   Train Loss: 10.360   R^2: 0.883
# Epoch: 610   Train Loss: 10.351   R^2: 0.885
# Epoch: 620   Train Loss: 9.961   R^2: 0.890
# Epoch: 630   Train Loss: 9.784   R^2: 0.896
# Epoch: 640   Train Loss: 10.081   R^2: 0.888
# Epoch: 650   Train Loss: 10.268   R^2: 0.886
# Epoch: 660   Train Loss: 10.230   R^2: 0.888
# Epoch: 670   Train Loss: 10.312   R^2: 0.886
# Epoch: 680   Train Loss: 9.660   R^2: 0.896
# Epoch: 690   Train Loss: 9.675   R^2: 0.887
# Epoch: 700   Train Loss: 9.867   R^2: 0.891
# Epoch: 710   Train Loss: 9.698   R^2: 0.892
# Epoch: 720   Train Loss: 10.177   R^2: 0.880
# Epoch: 730   Train Loss: 9.590   R^2: 0.893
# Epoch: 740   Train Loss: 11.138   R^2: 0.877
# Epoch: 750   Train Loss: 9.906   R^2: 0.895
# Epoch: 760   Train Loss: 10.502   R^2: 0.883
# Epoch: 770   Train Loss: 10.369   R^2: 0.884
# Epoch: 780   Train Loss: 9.957   R^2: 0.892
# Epoch: 790   Train Loss: 9.889   R^2: 0.894
# Epoch: 800   Train Loss: 10.291   R^2: 0.887
# Epoch: 810   Train Loss: 10.638   R^2: 0.880
# Epoch: 820   Train Loss: 10.402   R^2: 0.889
# Epoch: 830   Train Loss: 9.627   R^2: 0.891
# Epoch: 840   Train Loss: 9.620   R^2: 0.893
# Epoch: 850   Train Loss: 10.592   R^2: 0.886
# Epoch: 860   Train Loss: 9.592   R^2: 0.894
# Epoch: 870   Train Loss: 9.918   R^2: 0.890
# Epoch: 880   Train Loss: 10.269   R^2: 0.889
# Epoch: 890   Train Loss: 9.925   R^2: 0.889
# Epoch: 900   Train Loss: 10.123   R^2: 0.889
# Epoch: 910   Train Loss: 10.589   R^2: 0.887
# Epoch: 920   Train Loss: 10.775   R^2: 0.879
# Epoch: 930   Train Loss: 10.574   R^2: 0.883
# Epoch: 940   Train Loss: 10.204   R^2: 0.888
# Epoch: 950   Train Loss: 10.022   R^2: 0.893
# Epoch: 960   Train Loss: 10.403   R^2: 0.877
# Epoch: 970   Train Loss: 9.849   R^2: 0.891
# Epoch: 980   Train Loss: 9.956   R^2: 0.886
# Epoch: 990   Train Loss: 10.457   R^2: 0.885
# Epoch: 1000   Train Loss: 9.849   R^2: 0.894
# training R2:  0.9021473323747902

# %%
nepochs = len(a_tr_Rsq)
plt.plot(np.arange(1,nepochs+1), a_tr_Rsq, 'o-', linewidth=1)
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('Train accuracy')
# Out:
# Text(0, 0.5, 'Train accuracy')

# %%
nsteps = len(a_tr_loss)
ntr = Xtr.shape[0]
epochs = np.arange(1,nsteps+1)*batch_size/ntr
plt.semilogy(epochs, a_tr_loss)
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.grid()
plt.xlim([0,np.max(epochs)])
plt.tight_layout()

# %%
# save the model: you must use the .pth format for pytorch models!
model_savepath = 'model.pth'

# To save a PyTorch model, we first pass an input through the model, 
# and then save the "trace". 
# For this purpose, we can use any input. 
# We will create a random input with the proper dimension.
x = torch.randn(26) # random input
x = x[None,:] # add singleton batch index
with torch.no_grad():
    traced_cell = torch.jit.trace(model, (x))

# Now we save the trace
torch.jit.save(traced_cell, model_savepath)
# Out:
# C:\Users\BassD\anaconda3\lib\site-packages\torch\jit\_trace.py:1084: TracerWarning: Output nr 1. of the traced function does not match the corresponding output of the Python function. Detailed error:
# Tensor-likes are not close!
#
# Mismatched elements: 1 / 1 (100.0%)
# Greatest absolute difference: 0.36865234375 at index (0, 0) (up to 1e-05 allowed)
# Greatest relative difference: 0.1078543140888604 at index (0, 0) (up to 1e-05 allowed)
#   _check_trace(

# %%
# generate kaggle submission file using the validation script
# !python {"validation.py " + model_savepath + " --Xts_path " + Xts_savepath + " --Xtr_path " + Xtr_savepath + " --yts_hat_path " + yts_hat_savepath }
# Out:
# training R2 =  0.900116595253781
# test target predictions saved in yts_hat_pytorch.csv
